# %%
import librosa
import os
import torch
import torchaudio
from unitspeech.speaker_encoder.ecapa_tdnn import ECAPA_TDNN_SMALL
from conf.hydra_config import MainConfig
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

try:
    path
except:
    path = "../"
    os.chdir(path)

# %%
cfg = MainConfig
device = torch.device("cuda" if torch.cuda.is_available() and cfg.train.on_GPU else "cpu")

print(f"Running from {os.getcwd()}")
print(f"Device: {device}")
# Out:
# Running from /workspace/local
# Device: cuda

# %%
column_names = ['path', 'transcript', 'speaker_id']

reference_speech_samples = pd.read_csv('evaluation/evaluation.csv', delimiter="|", header=None, names=column_names)
# reference_speech_samples = pd.read_csv('evaluation/synthesized_audio_CONDY.csv', delimiter="|", header=None, names=column_names)
# reference_speech_samples = pd.read_csv('evaluation/synthesized_audio_CONDY_sv56.csv', delimiter="|", header=None, names=column_names)

# synthesized_speech_samples = pd.read_csv('evaluation/synthesized_audio_AWGN.csv', delimiter="|", header=None, names=column_names)
# synthesized_speech_samples = pd.read_csv('evaluation/synthesized_audio_AWGN_sv56.csv', delimiter="|", header=None, names=column_names)
synthesized_speech_samples = pd.read_csv('evaluation/synthesized_audio_AWGN_500_sv56.csv', delimiter="|", header=None, names=column_names)

synthesized_speech_samples.value_counts()
# Out:
# path                                                              transcript                                                                           speaker_id
# /outputs/evaluation/with-finetune_AWGN_500_sv56/bal_ivan_026.wav  Mulțumesc dumneavoastră, zise Ivan, tresărind.                                       0             1
# /outputs/evaluation/with-finetune_AWGN_500_sv56/mrl_rnd1_221.wav  La fiecare zgomot tresăream, de câte ori auzeam sirene mă ascundeam.                 24            1
# /outputs/evaluation/with-finetune_AWGN_500_sv56/mrl_rnd2_044.wav  În acest caz, nu se poate spune de o schimbare.                                      24            1
# /outputs/evaluation/with-finetune_AWGN_500_sv56/mrl_rnd2_031.wav  Apă otrăvită, după cum veți vedea în cele ce urmează.                                24            1
# /outputs/evaluation/with-finetune_AWGN_500_sv56/mrl_rnd1_493.wav  Nu a murit, dar a rămas mutilată și asta m-a marcat.                                 24            1
#                                                                                                                                                                     ..
# /outputs/evaluation/with-finetune_AWGN_500_sv56/bvl_rnd2_411.wav  Regia este semnată de maestrul Cezar Ghioca.                                         6             1
# /outputs/evaluation/with-finetune_AWGN_500_sv56/bvl_rnd2_406.wav  Înmormântarea artistului va avea loc sâmbătă, la Eforie Sud, localitatea sa natală.  6             1
# /outputs/evaluation/with-finetune_AWGN_500_sv56/bvl_rnd2_382.wav  Ce drum ai dori să urmezi în viață.                                                  6             1
# /outputs/evaluation/with-finetune_AWGN_500_sv56/bvl_rnd2_290.wav  Dacă reapar showurile de profil, înseamnă că publicul le cere.                       6             1
# /outputs/evaluation/with-finetune_AWGN_500_sv56/smm_rnd3_497.wav  Le-a crescut tatăl, invalid de război, și mătușa Paraschiva.                         37            1
# Name: count, Length: 500, dtype: int64

# %% [markdown]
# # Get a list of the unique speakers

# %%
speakers = synthesized_speech_samples.speaker_id.unique()
speakers
# Out:
# array([ 0,  6,  8, 24, 37])

# %% [markdown]
# # Real Time Factor (RTF)

# %%
processing_time_50 = np.load("evaluation/processing_time_with-finetune_AWGN.npy")
print(f"Processing time mean: {processing_time_50.mean():.2f}")
print(f"Processing time max: {processing_time_50.max():.2f}")
print(f"Processig time min: {processing_time_50.min():.2f}")
speech_duration_50 = np.load("evaluation/speech_duration_with-finetune_AWGN.npy")
print(f"Speech duration mean: {speech_duration_50.mean():.2f}")
print(f"Speech duration max: {speech_duration_50.max():.2f}")
print(f"Speech duration min: {speech_duration_50.min():.2f}")
# Compute real time factor
RTF = processing_time_50.mean() / speech_duration_50.mean()
print(f"Average Real time factor AWGN: {RTF:.4f}")

# processing_time = np.load("evaluation/processing_time_with-finetune_CONDY.npy")
# print(f"Processing time mean: {processing_time.mean():.2f}")
# print(f"Processing time max: {processing_time.max():.2f}")
# print(f"Processig time min: {processing_time.min():.2f}")
# speech_duration = np.load("evaluation/speech_duration_with-finetune_CONDY.npy")
# print(f"Speech duration mean: {speech_duration.mean():.2f}")
# print(f"Speech duration max: {speech_duration.max():.2f}")
# print(f"Speech duration min: {speech_duration.min():.2f}")
# # Compute real time factor
# RTF = processing_time.mean() / speech_duration.mean()
# print(f"Average Real time factor CONDY: {RTF:.4f}")

processing_time_500 = np.load("evaluation/processing_time_with-finetune_AWGN_500.npy")
print(f"Processing time mean: {processing_time_500.mean():.2f}")
print(f"Processing time max: {processing_time_500.max():.2f}")
print(f"Processig time min: {processing_time_500.min():.2f}")
speech_duration_500 = np.load("evaluation/speech_duration_with-finetune_AWGN_500.npy")
print(f"Speech duration mean: {speech_duration_500.mean():.2f}")
print(f"Speech duration max: {speech_duration_500.max():.2f}")
print(f"Speech duration min: {speech_duration_500.min():.2f}")
# Compute real time factor
RTF = processing_time_500.mean() / speech_duration_500.mean()
print(f"Average Real time factor: {RTF:.4f}")
# Out:
# Processing time mean: 3.67
# Processing time max: 8.80
# Processig time min: 1.01
# Speech duration mean: 3.98
# Speech duration max: 9.67
# Speech duration min: 0.67
# Average Real time factor AWGN: 0.9224
# Processing time mean: 33.81
# Processing time max: 81.37
# Processig time min: 9.12
# Speech duration mean: 3.98
# Speech duration max: 9.67
# Speech duration min: 0.67
# Average Real time factor: 8.4981

# %% [markdown]
# - Value < 1: The program is faster than real time -> system can be used to genereate speech in real time applications

# %%
speaker_id = [0, 6, 8, 24, 37]
num_speakers = 5
samples_per_speaker = 100
colors = plt.cm.rainbow(np.linspace(0, 1, num_speakers))

plt.figure(figsize=(10, 6))
for i in range(num_speakers):
    start_idx = i * samples_per_speaker
    end_idx = (i + 1) * samples_per_speaker
    plt.scatter(speech_duration_50[start_idx:end_idx], processing_time_50[start_idx:end_idx], color=colors[i])
for i in range(num_speakers):
    start_idx = i * samples_per_speaker
    end_idx = (i + 1) * samples_per_speaker
    plt.scatter(speech_duration_500[start_idx:end_idx], processing_time_500[start_idx:end_idx], color=colors[i])
# Add title and labels
plt.xlabel("Speech duration [s]")
plt.ylabel("Processing time [s]")
plt.savefig("RTF_all.png")

# %% [markdown]
# # Mean Opinion Score (MOS)

# %%
import torch
import torchaudio as ta
from s3prl.hub import mos_wav2vec2
import torchaudio as ta

mos_predictor = mos_wav2vec2().cuda()
# Out:
# 2024-06-30 11:51:47 | INFO | s3prl.util.download | Requesting URL: https://www.dropbox.com/s/s9zpouk5svu1a4l/wav2vec2-dev-SRCC-best.ckpt?dl=1
# 2024-06-30 11:51:48 | INFO | s3prl.util.download | Using URL's local file: /root/.cache/s3prl/download/0d88c598bf659c310090af843bce281b4a3e558ddf80f59b7e1bb71b5bece17e.wav2vec2-dev-SRCC-best.ckpt?dl=1
# 2024-06-30 11:51:49 | INFO | s3prl.util.download | Requesting URL: https://huggingface.co/s3prl/converted_ckpts/resolve/main/wav2vec_small.pt
# 2024-06-30 11:51:49 | INFO | s3prl.util.download | Using URL's local file: /root/.cache/s3prl/download/aa064e275fe0123a0e1b515f2341bbe4408368510d91d0a6816f2822a6e5acdd.wav2vec_small.pt
# [Featurizer] - Take a list of 13 features and weighted sum them.
# [Featurizer] - The selected feature hidden_states's downsample rate is 320

# %% [markdown]
# # Experiment - MOS of original dataset

# %%
SAMPLE_RATE = 16_000
crnt_mos_scores = np.array([])
df = pd.read_csv(
    "evaluation/data_split_TEMP/metadata_SWARA1.0_text.csv", delimiter="|", header=None, names=column_names
)
df = df.sample(frac=1).reset_index(drop=True)

for index, row in df.iterrows():
    audio, sr = ta.load(row.path)
    audio = ta.transforms.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)(audio).to(device)
    with torch.no_grad():
        mos_score = mos_predictor(audio)["scores"]
    crnt_mos_scores = np.append(crnt_mos_scores, mos_score.cpu().numpy())
crnt_mos_scores.mean()
# Out:
# [NeMo W 2024-06-19 20:38:43 nemo_logging:349] /root/miniconda3/envs/unitspeech_3.8/lib/python3.8/site-packages/s3prl/upstream/mos_prediction/model.py:98: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#       att_w = softmax(self.W(batch_rep).squeeze(-1)).unsqueeze(-1)
# 3.2696068091786317

# %% [markdown]
# - OBS mean MOS over train dataset was: 3.2696068091786317

# %% [markdown]
# - From 2K random samples we get around 3.3 MOS score

# %% [markdown]
# # Experiment - MOS of synthesized samples

# %%
SAMPLE_RATE = 16_000
mos_scores = {}
for speaker in speakers:
    crnt_mos_scores = np.array([])
    speaker_samples = synthesized_speech_samples[synthesized_speech_samples.speaker_id == speaker]
    for index, row in speaker_samples.iterrows():
        audio, sr = ta.load(row.path)
        audio = ta.transforms.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)(audio).to(device)
        with torch.no_grad():
            mos_score = mos_predictor(audio)['scores']
        crnt_mos_scores = np.append(crnt_mos_scores, mos_score.cpu().numpy())
    mos_scores[speaker] = crnt_mos_scores
# Out:
# /root/miniconda3/envs/unitspeech_3.8/lib/python3.8/site-packages/s3prl/upstream/mos_prediction/model.py:98: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   att_w = softmax(self.W(batch_rep).squeeze(-1)).unsqueeze(-1)
# Index: 53, MOS: tensor([3.5653])
# Index: 205, MOS: tensor([3.5326])
# Index: 230, MOS: tensor([3.5359])
# Index: 233, MOS: tensor([3.5380])
# Index: 357, MOS: tensor([3.5451])
# Index: 389, MOS: tensor([3.6227])

# %%
for speaker, scores in mos_scores.items():
    print(f"Speaker: {speaker}")
    print(f"\tMean MOS: {scores.mean():.2f}")
    print(f"\tMax MOS: {scores.max():.2f}")
    print(f"\tMin MOS: {scores.min():.2f}")
# Out:
# Speaker: 0
# 	Mean MOS: 3.23
# 	Max MOS: 3.57
# 	Min MOS: 2.80
# Speaker: 6
# 	Mean MOS: 3.24
# 	Max MOS: 3.42
# 	Min MOS: 3.01
# Speaker: 8
# 	Mean MOS: 3.36
# 	Max MOS: 3.54
# 	Min MOS: 3.18
# Speaker: 24
# 	Mean MOS: 3.40
# 	Max MOS: 3.62
# 	Min MOS: 3.20
# Speaker: 37
# 	Mean MOS: 3.31
# 	Max MOS: 3.49
# 	Min MOS: 3.12

# %%
global_mos = np.mean([score for speaker, scores in mos_scores.items() for score in scores])
print(f"MOS for all speakers: {global_mos:.2f}")
# Out:
# MOS for all speakers: 3.31

# %% [markdown]
# - 3.28 - fara sv56 - same MOS W/WO condy
# - 3.31 - cu sv56 in ambele cazuri
# - 3.33 - cu sv56 AWGN si 500 iteratii pentru a genera

# %% [markdown]
# # Speaker Cosine Similarity

# %%
speaker_encoder_path = "/checkpoints/EVALUATION/speaker_encoder/checkpts/speaker_encoder.pt"

# Speaker Encoder for extracting speaker embedding
print("Initializing Speaker Encoder...")
spk_embedder = ECAPA_TDNN_SMALL(feat_dim=1024, feat_type="wavlm_large", config_path=None)
state_dict = torch.load(speaker_encoder_path, map_location=lambda storage, loc: storage)
spk_embedder.load_state_dict(state_dict["model"], strict=False)
_ = spk_embedder.cuda().eval()
# Out:
# Initializing Speaker Encoder...
# Using cache found in /root/.cache/torch/hub/s3prl_s3prl_main
# 2024-06-30 11:58:05 | INFO | s3prl.util.download | Requesting URL: https://huggingface.co/s3prl/converted_ckpts/resolve/main/wavlm_large.pt
# 2024-06-30 11:58:05 | INFO | s3prl.util.download | Using URL's local file: /root/.cache/s3prl/download/f2d5200177fd6a33b278b7b76b454f25cd8ee866d55c122e69fccf6c7467d37d.wavlm_large.pt
# 2024-06-30 11:58:07 | INFO | s3prl.upstream.wavlm.WavLM | WavLM Config: {'extractor_mode': 'layer_norm', 'encoder_layers': 24, 'encoder_embed_dim': 1024, 'encoder_ffn_embed_dim': 4096, 'encoder_attention_heads': 16, 'activation_fn': 'gelu', 'layer_norm_first': True, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'feature_grad_mult': 1.0, 'normalize': True, 'dropout': 0.0, 'attention_dropout': 0.0, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.0, 'dropout_input': 0.0, 'dropout_features': 0.0, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': 'static', 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': 'static', 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'relative_position_embedding': True, 'num_buckets': 320, 'max_distance': 800, 'gru_rel_pos': True}
# /root/miniconda3/envs/unitspeech_3.8/lib/python3.8/site-packages/torch/nn/functional.py:4999: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(

# %%
from torch import cosine_similarity

if len(synthesized_speech_samples) != len(reference_speech_samples):
    raise ValueError("The number of samples in the reference and synthesized datasets do not match.")

SCS = {speaker: np.array([]) for speaker in speakers}

for (idx_ref, row_ref), (idx_synth, row_synth) in zip(
    reference_speech_samples.iterrows(), synthesized_speech_samples.iterrows()
):
    transcript_ref = row_ref.transcript
    transcript_synth = row_synth.transcript
    assert row_ref.speaker_id == row_synth.speaker_id, f"Speaker ID mismatch at index {idx_ref}."
    assert transcript_ref == transcript_synth, "Transcripts dont match "

    spk_id = row_ref.speaker_id
    path_ref = row_ref.path
    path_syth = row_synth.path

    wav_ref, sr_ref = librosa.load(path_ref)
    wav_ref = torch.FloatTensor(wav_ref).unsqueeze(0)
    resample_fn = torchaudio.transforms.Resample(sr_ref, cfg.spkr_embedder.sr).cuda()
    wav_ref = resample_fn(wav_ref.cuda())
    spk_emb_ref = spk_embedder(wav_ref)

    wav_synth, sr_synth = librosa.load(path_syth)
    wav_synth = torch.FloatTensor(wav_synth).unsqueeze(0)
    resample_fn = torchaudio.transforms.Resample(sr_synth, cfg.spkr_embedder.sr).cuda()
    wav_synth = resample_fn(wav_synth.cuda())
    spk_emb_synth = spk_embedder(wav_synth)

    output = cosine_similarity(spk_emb_ref, spk_emb_synth, dim=1)
    SCS[spk_id] = np.append(SCS[spk_id], output.detach().cpu().numpy())
# Out:
# /root/miniconda3/envs/unitspeech_3.8/lib/python3.8/site-packages/torch/nn/functional.py:4999: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(

# %%
for speaker, scores in SCS.items():
    print(f"Speaker: {speaker}")
    print(f"\tMean Speaker Cosine Similarity: {scores.mean():.2f}")
    print(f"\tMax Speaker Cosine Similarity: {scores.max():.2f}")
    print(f"\tMin Speaker Cosine Similarity: {scores.min():.2f}")
# Out:
# Speaker: 0
# 	Mean Speaker Cosine Similarity: 0.52
# 	Max Speaker Cosine Similarity: 0.72
# 	Min Speaker Cosine Similarity: 0.23
# Speaker: 6
# 	Mean Speaker Cosine Similarity: 0.47
# 	Max Speaker Cosine Similarity: 0.70
# 	Min Speaker Cosine Similarity: -0.09
# Speaker: 8
# 	Mean Speaker Cosine Similarity: 0.47
# 	Max Speaker Cosine Similarity: 0.65
# 	Min Speaker Cosine Similarity: 0.05
# Speaker: 24
# 	Mean Speaker Cosine Similarity: 0.57
# 	Max Speaker Cosine Similarity: 0.70
# 	Min Speaker Cosine Similarity: 0.31
# Speaker: 37
# 	Mean Speaker Cosine Similarity: 0.43
# 	Max Speaker Cosine Similarity: 0.62
# 	Min Speaker Cosine Similarity: 0.21

# %%
global_scs = np.mean([score for speaker, scores in SCS.items() for score in scores])
print(f"SCS for all speakers: {global_scs:.4f}")
# Out:
# SCS for all speakers: 0.4923

# %% [markdown]
# # AWGN + 50 it
# - Speaker: 0
# 	- Mean Speaker Cosine Similarity: 0.52
# 	- Max Speaker Cosine Similarity: 0.72
# 	- Min Speaker Cosine Similarity: 0.23
# - Speaker: 6
# 	- Mean Speaker Cosine Similarity: 0.47
# 	- Max Speaker Cosine Similarity: 0.70
# 	- Min Speaker Cosine Similarity: -0.09
# - Speaker: 8
# 	- Mean Speaker Cosine Similarity: 0.47
# 	- Max Speaker Cosine Similarity: 0.65
# 	- Min Speaker Cosine Similarity: 0.05
# - Speaker: 24
# 	- Mean Speaker Cosine Similarity: 0.57
# 	- Max Speaker Cosine Similarity: 0.70
# 	- Min Speaker Cosine Similarity: 0.31
# - Speaker: 37
# 	- Mean Speaker Cosine Similarity: 0.43
# 	- Max Speaker Cosine Similarity: 0.62
# 	- Min Speaker Cosine Similarity: 0.21
#
# SCS for all speakers: 0.4923

# %% [markdown]
# ## AWGN + SV56 + 50 it
#
# - Speaker: 0
# 	- Mean Speaker Cosine Similarity: 0.52
# 	- Max Speaker Cosine Similarity: 0.72
# 	- Min Speaker Cosine Similarity: 0.23
# - Speaker: 6
# 	- Mean Speaker Cosine Similarity: 0.47
# 	- Max Speaker Cosine Similarity: 0.70
# 	- Min Speaker Cosine Similarity: -0.08
# - Speaker: 8
# 	- Mean Speaker Cosine Similarity: 0.47
# 	- Max Speaker Cosine Similarity: 0.65
# 	- Min Speaker Cosine Similarity: 0.05
# - Speaker: 24
# 	- Mean Speaker Cosine Similarity: 0.57
# 	- Max Speaker Cosine Similarity: 0.70
# 	- Min Speaker Cosine Similarity: 0.31
# - Speaker: 37
# 	- Mean Speaker Cosine Similarity: 0.43
# 	- Max Speaker Cosine Similarity: 0.62
# 	- Min Speaker Cosine Similarity: 0.21
#
# - SCS for all speakers: 0.4924

# %% [markdown]
# ## 500 iterations + sv56
#
# - Speaker: 0
# 	- Mean Speaker Cosine Similarity: 0.51
# 	- Max Speaker Cosine Similarity: 0.70
# 	- Min Speaker Cosine Similarity: 0.20
# - Speaker: 6
# 	- Mean Speaker Cosine Similarity: 0.49
# 	- Max Speaker Cosine Similarity: 0.70
# 	- Min Speaker Cosine Similarity: -0.08
# - Speaker: 8
# 	- Mean Speaker Cosine Similarity: 0.48
# 	- Max Speaker Cosine Similarity: 0.64
# 	- Min Speaker Cosine Similarity: 0.09
# - Speaker: 24
# 	- Mean Speaker Cosine Similarity: 0.57
# 	- Max Speaker Cosine Similarity: 0.70
# 	- Min Speaker Cosine Similarity: 0.35
# - Speaker: 37
# 	- Mean Speaker Cosine Similarity: 0.44
# 	- Max Speaker Cosine Similarity: 0.63
# 	- Min Speaker Cosine Similarity: 0.26
# - SCS for all speakers: 0.4993

# %% [markdown]
# ## WER and CER

# %%
# https://github.com/openai/whisper/tree/main?tab=readme-ov-file
import whisper
lang = "ro_ro"

model = whisper.load_model("medium").cuda()
print(
    f"Model is {'multilingual' if model.is_multilingual else 'English-only'} "
    f"and has {sum(np.prod(p.shape) for p in model.parameters()):,} parameters."
)
# Out:
# Model is multilingual and has 762,321,920 parameters.

# %%
import re

def normalize_text(text: str) -> str:
    chars_to_ignore_regex = '[,?.!\-\;\:"“%‘”�—’…–„]'

    text = re.sub(chars_to_ignore_regex, "", text.lower())

    # In addition, we can normalize the target text, e.g. removing new lines characters etc...
    # note that order is important here!
    token_sequences_to_ignore = ["\n\n", "\n", "   ", "  "]

    for t in token_sequences_to_ignore:
        text = " ".join(text.split(t))
    return text

# %%
import IPython.display as ipd
from jiwer import wer, cer

options = whisper.DecodingOptions()

wer_all = np.array([])
cer_all = np.array([])

for idx, row in synthesized_speech_samples.iterrows():
    path = row.path
    transcript = normalize_text(row.transcript)
    audio = whisper.load_audio(path)
    audio = whisper.pad_or_trim(audio)
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    hypothesis = normalize_text(whisper.decode(model, mel, options).text)

    print(f"Transcript: {transcript}")
    print(f"Decoded: {hypothesis}")

    wer_all = np.append(wer_all, wer(transcript, hypothesis))
    cer_all = np.append(cer_all, cer(transcript, hypothesis))
# Out:
# Transcript: nu în fața prefecturii
# Decoded: nu în fața prefecturii
# Transcript: o lună este enorm sunt ca terminat spune micul muzician
# Decoded: o lună este enorm sunt ca terminați spune micul muzician
# Transcript: în consecință pot acționa mai rapid și mai eficient
# Decoded: în consecință pot acționa mai rapid și mai eficient
# Transcript: mie mi sa reproșat adesea că distrug prestigiul universității atacând găștile universitare
# Decoded: mie mi sa reproșat adesea că distrug prestigiul universității atacând găștile universitare
# Transcript: toate acestea au fost confiscate și distruse
# Decoded: toate acestea au fost confiscate și distruse
# Transcript: sportiv poate pentru că și fratele meu a făcut box
# Decoded: sportiv poate pentru ca si fratele meu au facut boc
# Transcript: alte cincizeci de posturi dedicate muncitorilor sunt disponibile în hunedoara
# Decoded: alte 50 de posturi dedicate muncitorilor sunt disponibile în hunedoara
# Transcript: unii patroni închid unitățile alții caută soluții de redresare
# Decoded: unii patroni închid unitățile alții caută soluții de redresare
# Transcript: antrenorul lui dinamo șia făcut temele înaintea meciului de astăzi
# Decoded: antrenorul lui dinamo șia făcut temele înaintea meciului de astăzi
# Transcript: îmi plac cartofii prăjiți foarte mult a spus gabriel safta
# Decoded: îmi plac cartofii prăjiți foarte mult a spus gabriel safta
# Transcript: pe masa procurorilor parchetului de pe lângă judecătoria constanța
# Decoded: pe masa procurorilor parchietului de pe lângă judecătoria constanța
# Transcript: el a intervenit și atunci când după demisia mea sa forțat creșterea
# Decoded: el a intervenit și atunci când după demisia mea sa forțat creșterea
# Transcript: nu pot să le uit pe astea niciodată
# Decoded: nu pot să le uit pe astea niciodată
# Transcript: încerc să respect tradițiile în care am fost crescut
# Decoded: încerc să respect tradițiile în care am fost crescut
# Transcript: sunt restanțe la acordarea salariilor de merit la acordarea tichetelor de masă
# Decoded: sunt restanțe la acordarea salarilor de merit la acordarea tichetelor de masă
# Transcript: polițiștii lau prins după ce au găsit numărul lui de telefon în agenda îndrăgitei cântărețe
# Decoded: polițiștii lau prins după ce au găsit numărul lui de telefon în agenda îndrăgitei cântărețe
# Transcript: mau luat cu forța și nu miau dat decât apă
# Decoded: mau luat cu forța și nu miau dat decât apă
# Transcript: aceștia au suferit arsuri ușoare la mâini față și cap
# Decoded: aceștia au suferit arsuriușoare la mâini față și cap
# Transcript: miar fi plăcut să lucrez în domeniul arhitecturii însă nu am reușit
# Decoded: miar fi plăcut să lucrez în domeniul arhitecturii însă nu am reușit
# Transcript: pe lângă clienții fideli locul de joacă are asigurată clientela din rândul părinților care își fac cumpărăturile în supermarket
# Decoded: pe lângă clienții fidel locul de joacă are asigurată clientela din rândul părinților care își fac umpărăturile în supermarket
# Transcript: nui vorbă că știa vidma ceo aștepta dar ce era să facă
# Decoded: nui vorba ca stia vilma ce o astepta dar ce era sa faca
# Transcript: au fost fete care sau lăsat de handbal
# Decoded: au fost fete care sau lăsat de hambal
# Transcript: dar toates până la o vreme fătul meu
# Decoded: dar toate spână la o vreme fătul meu
# Transcript: nu mai sunt bani
# Decoded: nu mai sunt bani
# Transcript: sa petrecut de ziua orașului oradea
# Decoded: sau pe trecut de ziua orașului oradea
# Transcript: de asemenea covei a fost iertat de magistrați și în alte rânduri
# Decoded: de asemenea covei a fost iertat de magistrați și în alte rânduri
# Transcript: doar în primele zile inspectorii au confiscat aproape jumătate de kilogram de aur nemarcat de la bijuteriile din timișoara
# Decoded: doar în primele zile inspectorii au confiscat aproape jumătate de kilogram de aur nemarcat de la bijuterile din timișoara
# Transcript: nu aveau ei cum să intre pe stadion chiar dacă vroiau
# Decoded: nu aveau ei cum să intre pe stadion chiar dacă voiau
# Transcript: atacantul din republica moldova îi ia locul lui cristi constantin
# Decoded: atacantul din republica moldova ia locul lui cristi constantin
# Transcript: este vorba de un sistem de climatizare arhitectură electronică și suspensii inovatoare
# Decoded: este vorba de un sistem de climatizare arhitectură electronică și suspenții inovatoare
# Transcript: raikkonen nu a reușit să iasă din pluton în primele tururi
# Decoded: raikonen nu a reușit să iasă din pluton în primele tururi
# Transcript: fiecare cameră dispune de grup sanitar în cameră
# Decoded: fiecare cameră dispune de grup sanitar în cameră
# Transcript: apreciez această acțiune și sper ca numărul câinilor comunitari să se reducă a spus gheorghița dina
# Decoded: aprecize aceasta acțiune și sper ca numărul câinilor comunitari să se reducă a spus gheorghița dina
# Transcript: echipa a arătat acel spirit care nea făcut să câștigăm campionatul
# Decoded: echipa a arătat acel spirit care nea făcut să câștigăm campionatul
# Transcript: atunci vânătorul șia dat seama că este în fața unui record
# Decoded: atunci vânătorul șia dat seama că este în fața unui record
# Transcript: sâmbătă noaptea se va circula însă pe o singură bandă
# Decoded: zâmbătă noaptea se va circula însă pe o singură bandă
# Transcript: a jucat teatru sa prefăcut că ia venit rău
# Decoded: a jucat teatru sa prefăcut că ea venit rău
# Transcript: de altfel am vrut să mă și retrag
# Decoded: de altfel am vrut să mă și retract
# Transcript: dar unde gândeai să fiu când asta mie slujba
# Decoded: dar unde gândeai să fiu când asta mie slujba
# Transcript: toate marile orașe acordă gratuitate elevilor
# Decoded: toate marile orasii acordă gratuitate elevilor
# Transcript: mă bucur foarte mult pentru reușita ei și îi vom pregăti o surpriză în clasă mai spune doina petrean
# Decoded: pă bucur foarte mult pentru reușita ei și vom pregăti o surpriză în clasă mai spune doina petrean
# Transcript: prețurile vor crește cu nouă la sută
# Decoded: prețurile vor crește cu 9
# Transcript: am putea pierde zece procente anul acesta
# Decoded: am putea pierde 10 anul acesta
# Transcript: neam fi pregătit la fel dacă jucam sau nu
# Decoded: neam fi pregătit la fel dacă jucam sau nu
# Transcript: primarii spun că nu mai au bani de salarii
# Decoded: primarii spun că nu mai au bani de salarii
# Transcript: acum nu iam mai luat pentru că adăpostul era plin cu câini
# Decoded: acum nu iam mai luat pentru ca adapostul era plin cu caini
# Transcript: scriam și în numele fetelor și ele erau printre cliente
# Decoded: scriam și numele fetelor și ele erau printre cliente
# Transcript: un procent de cincizeci de procente din populație trăiește la țară
# Decoded: un procent de 50 din populație trăiește la țară
# Transcript: am aflat de la comisarul șef ion iacobescu comandantul poliției costești
# Decoded: a dat la nimă al șin brău neau uitat cu comana în polița când străplat
# Transcript: drumul a fost blocat mai multe ore
# Decoded: drumul a fost blocat mai multe ore
# Transcript: deocamdată din constatările pe care leam făcut
# Decoded: deocamdată din constatările pe care leam făcut
# Transcript: probabil vreo unu zero unu doi
# Decoded: probabil vreo 1012
# Transcript: dar unde se găsesc de aceste
# Decoded: dar unde se găsesc de aceste
# Transcript: dar cum să nu fie
# Decoded: dar cum să nu fie
# Transcript: cotidianul the daily telegraph a alcătuit un top al plângerilor ciudate
# Decoded: cotidianul de daily telegraph a alcătuit un top al plângerilor ciudate
# Transcript: în urma impactului muncitorul a decedat pe loc
# Decoded: în urma impactului muncitorul a decedat pe loc
# Transcript: un bărbat și două femei din comuna moara nu sau lăsat păcăliți
# Decoded: un bărbat și două femei din comun amoara nu sau lăsat păcălii
# Transcript: mie îmi place să cred că ceea ce scriu eu este poezie
# Decoded: mie îmi place să cred că ceea ce scriu eu este poezie
# Transcript: asumarea răspunderii în parlament bilanțul președintelui se rupe sau nu guvernul
# Decoded: asumarea răspunderii în parlament bilanțul președintelui se rupe sau nu guvernul
# Transcript: cele două familii sunt în conflict de mai multă vreme
# Decoded: cele două familii sunt în conflict de mai multă vreme
# Transcript: este mult mai multă mizerie decât neam așteptat
# Decoded: este mult mai multă mizerie decât neam așteptat
# Transcript: acolo au doi antrenori de excepție
# Decoded: acolo au doi antrenori de excepție
# Transcript: sunt mulțumit numai de scor în rest este cel mai slab meci de când sunt la iași
# Decoded: sunt mulțumit numai de scor în rest este cel mai slab meci de când sunt la iaști
# Transcript: dacă reapar showurile de profil înseamnă că publicul le cere
# Decoded: dacă reapar șourile de profil înseamnă că publicul le cere
# Transcript: dar bine ivane iar ai de gând să mă chinuiești cu turbinca ceea a ta
# Decoded: dar bine ivane iar ai de gând să mă chinuiești cu turbinca cea ta
# Transcript: acțiunea sa desfășurat cu restricții de circulație cu filtru selectiv
# Decoded: acțiunea sa desfășurat cu restricții de circulație cu filtru selectiv
# Transcript: nam mai zburat niciodată dar cred că o să încerc acum
# Decoded: nam mai zburat niciodata dar cred că o să încerc acum
# Transcript: consiliul județean va demara în curând vânzarea cabinetelor medicale din policlinica giurgiu
# Decoded: consiliul județian va demara în curând vânzarea cabinetelor medicale din policlinica giurgiu
# Transcript: nu a murit dar a rămas mutilată și asta ma marcat
# Decoded: nu a murit dar a ramas mutilata si asta ma marcat
# Transcript: ancheta a început în ianuarie și sa finalizat în iulie a spus procurorul mihaela pop
# Decoded: ancheta a început în ianuarie și sa finalizat în iulie a spus procurorul mihaila pop
# Transcript: există o suspiciune de epizootie
# Decoded: există o suspiciune de epizodie
# Transcript: și un succes la diferență de un gol near mulțumi
# Decoded: și un succes la diferență de un gol near mulțumit
# Transcript: bate el ivan în poartă cât poate se răcăduiește el cu pușca dar au prins ei acum dracii la minte
# Decoded: bate el ivan în poartă cât poate se răcăduiește el cu pușca dar au prins ei acum draci și la minte
# Transcript: ea poate fi atacată cu apel la curtea federală de apel
# Decoded: ea poate fi atacata cu apel la curtea federala de apel
# Transcript: niciodată numi plăcea să pierd
# Decoded: niciodată numi placea să pierd
# Transcript: șaisprezece ani întro companie multinațională dintre care doisprezece ani pe poziția de director general este prea mult
# Decoded: 16 ani întro companie multinatională dintre care 12 ani pe poziția de director general este prea mult
# Transcript: este o măsură corectă declară bazac
# Decoded: este o măsură corectă declară bazac
# Transcript: palestinienii cer un îngheț complet al construcțiilor amintește agerpres
# Decoded: cu alestinieni cer un îngheț complet al construcților amintește ager prescu
# Transcript: soluția au găsito în franța la o firmă care folosește metoda ecologică de a curăța mașinile de patru ani
# Decoded: soluții au găsito în franța la o firmă care folosește metoda ecologică de a curăța mașinile de patru ani
# Transcript: de aceeași părere este și seril talpălaru inspectorul școlar general de iași
# Decoded: că ținel părțitătirită de lăsător caționea 2012
# Transcript: în sfârșit nu trece mult la mijloc iaca se pomenește ivan cu un car de palce cum îi plăcea lui
# Decoded: în sfârșit nu trece mult la mijloc ea ca să pomenește ivan cu un car de palce cum îi plăcea lui
# Transcript: magistrații curții de apel craiova își vor relua activitatea începând de astăzi
# Decoded: magistrații curții de apel craiova își vor reloa activitatea începând de astăzi
# Transcript: sunt corupți și au o strânsă și dârză legătură cu maimuțoiul
# Decoded: sunt corupți și au o strânsă și dârză legătură cu maimuțăiul
# Transcript: am visat de mulți ani să ajung acolo
# Decoded: am visat de mulți ani să ajung acolo
# Transcript: tânărul va fi îmbrăcat în mire
# Decoded: tânărul va fi îmbrăcat în mire
# Transcript: sunt o persoană care trăiește în prezent nu în viitor
# Decoded: sunt o persoană care trăiește în prezent nu în viitor
# Transcript: nu am muncit pentru bani chiar deloc pentru că aveam cemi trebuia
# Decoded: nu am muncit pentru bani chiar deloc pentru ca aveam cemi trebuia
# Transcript: mulțumesc dumneavoastră zise ivan tresărind
# Decoded: mulțumesc dumneavoastră zisă ivan tresărind
# Transcript: cum reușim iată doar o explicație
# Decoded: cum reușim iată doar o explicație
# Transcript: acesta se referă însă doar la proprietățile din capitală
# Decoded: acesta se referă însă doar la proprietățile din capitală
# Transcript: avem tot ce ne trebuie și nici nu ne costă mult
# Decoded: avem tot ce ne trebuie și nici nu ne costă mult
# Transcript: declară viceprimarul cornel ionică
# Decoded: declară viceprimarul cornel ionică
# Transcript: curtea lăcașului sfânt a devenit neîncăpătoare
# Decoded: curtea lăcașului sfânt a devenit neîncăpătoare
# Transcript: la trei inși în doisprezece zile plăteam trei mii șase sute lei
# Decoded: la 3 inși în 12 zile plăteam 3600 lei
# Transcript: studenții care învață la universitatea constantin brâncoveanu se confruntă cu o problemă deosebit de gravă
# Decoded: studenții care învață la universitatea constantin brâncoveanu se confrună cu o problemă deosebit de gravă
# Transcript: inima artistului sa oprit din cauza unei suferințe pulmonare severe
# Decoded: inima artistului sa oprit din cauza unei suferinte pulmonare severe
# Transcript: anul acesta niciun părinte nu a fost decăzut
# Decoded: anul acesta niciun părinte nu a fost decăzut
# Transcript: însă amintirile au și un alt rol
# Decoded: însă amintirele au și un alt rol
# Transcript: serbia este o echipă sub a franței ca organizare și valoare individuală
# Decoded: serbia este o echipă subba franței ca organizare și valoare individuală
# Transcript: cu dracii de la boierul cela ai făcut hara para
# Decoded: cu dracii de la boierul cel ai făcut a rapara
# Transcript: eu nu mai înțeleg pentru ce dau acei bani
# Decoded: eu nu mai inteleg pentru ce dau acei bani
# Transcript: acum cred că nu ții mai face blestem cu mine mii da drumul să intru la dumnezeu că tare mare treabă mai am
# Decoded: acum cred că nu ții mai face blestem cu mine mii da drumul să intru la dumnezeu că tare mare treabă mai am
# Transcript: toate amenajările sunt în conformitate cu normele inspectoratului de stat în construcții
# Decoded: toate amenajările sunt în conformitate cu normele inspectoratului de stat în construcții
# Transcript: nu mă interesează să fiu investitor
# Decoded: nu mă interesează să fiu investitor
# Transcript: ca ea mai este o singură femeie la unitatea de la bacău
# Decoded: caia mai este o singura femei la unitatea de la bacau
# Transcript: pe de altă parte conform rezultatelor obținute
# Decoded: pe de altă parte conform rezultatelor obținute
# Transcript: ce drum ai dori să urmezi în viață
# Decoded: ce drum ai dorit să urmezi în viață
# Transcript: vă spun sincer era mult mai bine cu un guvern de tehnicieni
# Decoded: vă spun sincer era mult mai bine cu un cuvern de tehnicieni
# Transcript: au venit peste noi și neau lovit cu bâte de baseball
# Decoded: au venit peste noi și neau lovit cu bute de beisbol
# Transcript: mia zis cineva de la cefere că bergodi e cam tralala
# Decoded: mia zis cineva de la ce ferecă bergodie cam tra lala
# Transcript: nu știam nici dacă e bine nici dacă e rău
# Decoded: nu știam nici dacă e bine nici dacă e rău
# Transcript: așa că am reușit să strâng mai multe bucăți din același manual
# Decoded: așa că am reușit să strâng mai multe bucăți din același manual
# Transcript: consecințele ar fi catastrofale pentru sportul francez a spus michel brun vicepreședintele cnosf
# Decoded: consecințele ar fi catastrofale pentru sportul francez a spus michel brun vicepreședintele cnos
# Transcript: ei tabacioc este
# Decoded: ei tabaciu este
# Transcript: regia este semnată de maestrul cezar ghioca
# Decoded: regia este semnată de maestrul cezar gheoca
# Transcript: la ultimul nivel al turnurilor va exista o scară exterioară pe care turiștii vor putea urca în cupola bisericii
# Decoded: la ultimul nivel al turnurilor va exista o scara exterioră pe care turisti vor putea urca în cupola bisericii
# Transcript: despărțirea de andreea pătrașcu la dat peste cap pe cabral
# Decoded: despărțirea de andreea pătrașcu la dat peste cap pe cabral
# Transcript: pe ecrane se perindau mai ales miniștri prim miniștri șefi de partid
# Decoded: pe ecrane se perindau mai ales ministrii primministrii șefi de partid
# Transcript: un motor bun ajunge și la șapte sute de euro
# Decoded: un motor bun ajunge și la 700 de euro
# Transcript: deocamdată nu simțim ca în alte județe efectele spune acesta
# Decoded: deocamdată nu simțim ca în alte județe efectele spune acesta
# Transcript: ia fugi deacolo săți arăt eu nebunule ce ești
# Decoded: ia fugi de acolo sati arat eu nebunule ce eci
# Transcript: miam ales o armă foarte grea o armă tehnică
# Decoded: miam ales o armă foarte grea o armă tehnică
# Transcript: acum negociază pentru achiziționarea unei a doua mori afacerile luând amploare
# Decoded: acum negociază pentru achiziționarea unei a doua mori afacirile luni de amploare
# Transcript: întrun cuvânt rusia dintotdeauna
# Decoded: întrun cuvânt rusia din totdeauna
# Transcript: responsabil pentru această stare de lucruri este consumul prea mare de alcool și fumatul excesiv
# Decoded: responsabil pentru această stare de lucruri este consumul prea mare de alcool și fumatul excesiv
# Transcript: cum reușim iată doar o explicație
# Decoded: cum reușim iată doar o explicație
# Transcript: de bunătățile tale ivane
# Decoded: de bunătățile tale ivane
# Transcript: algocalmin paracetamol sau aspirină sunt singurele tablete existente în dulăpioarele cabinetelor
# Decoded: algochalmin paracetamol sau aspirină sunt singurele tablete existente în dulăpioarele cabinetlor
# Transcript: eu doar lam împins pe primar
# Decoded: eu doar lam împins pe primar
# Transcript: deocamdată nu se cunoaște valoarea prejudiciului
# Decoded: deocamdată nu se cunoaște valoarea prejudiciului
# Transcript: poate mă mai așteaptă și alții să le dau răvaș de drum
# Decoded: poate mă mai așteaptă și alții să le dau răvași de drum
# Transcript: anul acesta niciun părinte nu a fost decăzut
# Decoded: anul acesta niciun părinte nu a fost decăzut
# Transcript: mam săturat și mam prea săturat sfinte petre
# Decoded: mam săturat și mam preasăturat sfinte petre
# Transcript: nu este o lege care săi interzică dar e un statut care nici nu este aprobat cel puțin
# Decoded: nu este o legă care să interzică dar e un statut care nici nu este aprobat cel puțin
# Transcript: avem ocazia să prezentăm un front unit
# Decoded: avem ocazia să prezentăm un front unic
# Transcript: este o victorie importantă pentru noi
# Decoded: este o victorie importantă pentru noi
# Transcript: familia este hotărâtă să ceară despăgubiri de la carmen bejan și sergiu florea
# Decoded: familia este hotărâtă să ceară de spăgubiri de la carmen bejan și sergiu florea
# Transcript: pentru mine pictura este ca o tabletă de inimă mă relaxează mă face să mă simt minunat
# Decoded: pentru mine pictura este ca o tabletă de inimă mă relaxează mă face să mă simt minunat
# Transcript: or mi sa părut scandalos
# Decoded: ori mi sa parut scandalos
# Transcript: preferam să mâncăm în cameră
# Decoded: preferam să mâncăm în cameră
# Transcript: viața mea a fost o luptă pentru a face bine oamenilor
# Decoded: viața mea a fost o luptă pentru a face bine oamenilor
# Transcript: înmormântarea artistului va avea loc sâmbătă la eforie sud localitatea sa natală
# Decoded: în mormântarea artistului va avea loc sâmbătă la eforie sud localitatea sa natală
# Transcript: finalul a fost dramatic pentru scandinav
# Decoded: finalul a fost dramatic pentru scandinav
# Transcript: pe lângă clienții fideli locul de joacă are asigurată clientela din rândul părinților care își fac cumpărăturile în supermarket
# Decoded: pe lângă clienții fidel locul de joacă are asigurată clientela din rândul părinților care își fac cumpărăturile în supermarche
# Transcript: de mâine vor proceda la fel și cei de la judecătoria slatina
# Decoded: demâine vor proceda la fel și cei de la judecătoria slatină
# Transcript: decât nam încotro trebuie să mă duc zise ea oftând
# Decoded: decât nam încotro trebuie să mă duc zi să iau stând
# Transcript: atunci sfântul petre întreabă dinlăuntru
# Decoded: atunci sfântul petre întreabă din lăuntru
# Transcript: în sfârșit mai stă el ivan oleacă așa cu fruntea rezemată pe mână șii și trăsnește în gând una
# Decoded: în sfârșit mai stăie livanole acasa cu frunțe arezemată pe mână și și trăsnește în gânduna
# Transcript: echipa de elevi a concurat în trei probe
# Decoded: echipa de elevia concurat în trei probe
# Transcript: nu este o zi ușoară pentru mine
# Decoded: nu este o zi ușoară pentru mine
# Transcript: toate secțiile spitalului în afară de blocul operator și secția nou născuți se confruntă cu problema lipsei lenjeriei curate
# Decoded: toate secțiile spitalului afara de blocul operator și secția nou născut se confrună cu problema lipsei lingeriei curate
# Transcript: aceștia au suferit arsuri ușoare la mâini față și cap
# Decoded: acesti au suferit arsuri ușoare la mâini față și cap
# Transcript: neamțul sa întâlnit ieri cu copos și susține că a ajuns la un acord în privința preluării rapidului
# Decoded: neamțul sa întâlnit ieri cu copos și susține că a ajuns la un acord în privința prelorii rapidului
# Transcript: am avut însă doar doi ani deschisă o casă de modă
# Decoded: am avut însă doar doi ani deschisă o casă de modă
# Transcript: ambele meciuri se vor disputa pe stadionul din urziceni
# Decoded: ambele meciuri se vor disputa pe stadionul din urziceni
# Transcript: nai grijă petre zise dumnezeu
# Decoded: nai grija petre zi se dumnezeu
# Transcript: deci sunt chestiuni extraordinar de importante
# Decoded: deci sunt chestiuni extraordinari de importante
# Transcript: până în luna septembrie alte peste treizeci de autorizații au fost eliberate pentru construcțiile rezidențiale din banat
# Decoded: până un luna septembrie alte peste 30 de autorizații au fost eliberate pentru construcțiile rezidențiale din banat
# Transcript: copilul a fost transportat la spitalul județean brașov pentru îngrijiri de specialitate
# Decoded: copilul a fost transportat la spitalul județean brașov pentru un grijir de specialitate
# Transcript: pentru a învinge steaua trebuie să fim hotărâți agresivi în sensul bun al cuvântului și să mușcăm din adversar
# Decoded: pentru ami vinge steaua trebuie sa fim hotarati agresivi in sensul bun al cuvantului si sa muscam din adersar
# Transcript: femeia este acuzată de săvârșirea infracțiunilor de înșelăciune și fals în înscrisuri sub semnătură privată
# Decoded: temia este acuzată de săvârșirea infracțiunilor de înșelăciune și fals în înscrisuri sub semnătură privată
# Transcript: nu trebuie un alt program economic al guvernului
# Decoded: nu trebuie un alt program economic al guvernului
# Transcript: și mia plăcut foarte tare
# Decoded: și mia plăcut foarte tare
# Transcript: îi place să confecționeze instrumente muzicale printre care și nai
# Decoded: îi place să confecționeze instrumente muzicale printre care și nai
# Transcript: acesta visează să ajungă în finala cupei româniei
# Decoded: acesta visează să ajungă în finala cupei româniei
# Transcript: tânăra are permisul de conducere de doar un an și jumătate
# Decoded: tânăl are permisul de conducere de doar un an și jumătate
# Transcript: mă descurc nam probleme spune valentin ușor îmbujorat
# Decoded: mă descur nam probleme spune valentin ușor îmbujurat
# Transcript: șia împachetat o valiză și se aventurează în forță spre tărâmul sfânt
# Decoded: și a împachetat o valiză și se aventurează în forță spre tărămul sfânt
# Transcript: lui marius nui place să fie mințit
# Decoded: lui marius nui place să fie minții
# Transcript: de pildă aș face un brand din brânza și gemurile locale
# Decoded: de pildă aș face un bran din brânza și gemurile locale
# Transcript: nu iert pe nimeni
# Decoded: nu iert pe nimeni
# Transcript: nu știu cine are dreptate sau nu
# Decoded: nu știu cine are dreptate sau nu
# Transcript: am împărtășit din informațiile primite în cadrul proiectului
# Decoded: am împărtășit din informațiile primite în cadrul proiectului
# Transcript: este o certitudine pentru toate serviciile noastre secrete
# Decoded: este o certitudine pentru toate servicile noastre secrete
# Transcript: asta se întâmpla atunci
# Decoded: asta se întâmplă atunci
# Transcript: cu dracii de la boierul cela ai făcut hara para
# Decoded: cu dracii de la boierul ce lai făcut a rapară
# Transcript: represiunea frica și distrugerea persoanei sunt evidente în unele dintre dialoguri
# Decoded: represiunea frica și distrugerea persoanei sunt evidente în unele dintre dialoguri
# Transcript: irimescu și nicola au fost foarte buni
# Decoded: irimescu și nicola au fost foarte buni
# Transcript: masmedia ne face probleme cu opinia publică
# Decoded: mas media ne face probleme cu opinia publică
# Transcript: secheli douăzeci și cinci
# Decoded: se aquele doaz é de xixin
# Transcript: mai mulți agenți sub acoperire filmează cu o cameră ascunsă toate neregulile
# Decoded: mai mulți agenți sub acotperire filmează cu o camera ascunsă toate neregulile
# Transcript: a fost impresionat și atras de lucrările lui darwin de istorie cultură și psihologie
# Decoded: a fost impresionat și atras de lucrările lui darwin de istorie cultură și psihologii
# Transcript: deacum ția venit și ție rândul să mori nam ceți face
# Decoded: de acum ția venit și ție rândul să mori nam ce ți face
# Transcript: am mers în jos
# Decoded: a mers în jos
# Transcript: ambele meciuri se vor disputa pe stadionul din urziceni
# Decoded: ambele meciuri se vor disputa pe stadionul din urziceni
# Transcript: dacă reapar showurile de profil înseamnă că publicul le cere
# Decoded: dacă reapar showurile de profil înseamnă că publicul le cere
# Transcript: e un punct pe care nul dai
# Decoded: e un punct pe care nul dai
# Transcript: acum mădălina a renunțat la handbal și a trecut la catedră
# Decoded: acum madalina a renunțat la handbal și a trecut la catedră
# Transcript: tatăl ei lucra în fostul combinat siderurgic iar familia la urmat
# Decoded: atelier lucra în fostul combinații de rulurgic iar familia a urmat
# Transcript: consolidarea terasamentului de aici a fost impusă ca urmare a inundațiilor din o mie nouă sute nouăzeci și nouă
# Decoded: consolidarea terra asamentului de aici a fost impusă ca urmare a inundaților din 1999
# Transcript: bucuria lor este atunci când papagalul începe să vorbească nea spus alina turcu proprietar de magazin
# Decoded: bucuria lor este atunci cand papagalul incepe sa vorbeasca nea spus alina turcu proprietar de magazini
# Transcript: dar până la vremea asta se adunase împrejurul lui ivan tot satul ca să vadă de patima dracilor
# Decoded: dar până la vremea asta se adunase împrejurul lui ivan tot satul ca să vadă de patima dracilor
# Transcript: a fost lovit la cap iar picioarele îi erau fracturate
# Decoded: a fost lovit la cap iar picioarele îi erau fracturate
# Transcript: avem în medie cam treizeci de spectacole pe an
# Decoded: avem în medie cam 30 de spectacole pe an
# Transcript: șoferul tirului a scăpat fără nicio leziune
# Decoded: șoferul tirului a scăpat fără nicio leziune
# Transcript: păcatul său este că nu le inspiră teamă celorlalți fotbaliști lucru care se reflectă și pe teren
# Decoded: păcatul său este că nu le inspiră teamă celorlalți fotbaliști lucru care se reflectă și vipe tetran
# Transcript: bine ivane zise boierul cu mulțumire
# Decoded: bine ivane zise boierul cu mulțumire
# Transcript: dacă fura vă dați seama că nu îmi mai cerea mie bani
# Decoded: dacă fura vă dați seama că nu mai cerea mie bani
# Transcript: lovea birourile a aruncat vreo trei scaune
# Decoded: lovea birourile a aruncat vreo 3 scaune
# Transcript: iară privitorii cu căciulile în mână îi urau drum bun ori încotro sa întoarce
# Decoded: iară privitorii cu căciulile în mână îi urau drum bun ori încotro santoarce
# Transcript: pe omul regiei îl pune acolo șeful său
# Decoded: pe omul regiei îl pune acolo şeful său
# Transcript: am gătit pentru mii de persoane până acum poate zeci de mii
# Decoded: am gătit pentru mii de persoane până acum poate zeci de mii
# Transcript: cred că va fi imposibil ca acel scenariu să se mai repete și joi
# Decoded: cred că va fi imposibil ca acel scenariu să se mai repete și joi
# Transcript: conform surselor citate acestea sunt ipoteze de lucru preliminare
# Decoded: conform surselor citate acestea sunt ipoteze de lucru preliminare
# Transcript: deacum dute pe apa sâmbetei și să ieși din raclă când tea scoate bunica din groapă
# Decoded: de acum dute pe apa zâmbetei și să ieși din raclă când tea scoate bunica din grapă
# Transcript: dar viața naște viață
# Decoded: dar viața naște viață
# Transcript: sper să joc și la bucurești la fel de bine
# Decoded: sper să joc și la bucurești la fel de bine
# Transcript: dar de la o vreme încoace cam de pe când țiam blagoslovit turbinca aceasta teai făcut prea nu știu cum
# Decoded: dar de la o vreme încoace cam de pe când ții am blagoslovit urbincă aceasta teai făcut prea nu știu cum
# Transcript: de asemenea ei solicită demiterea ministrului justiției
# Decoded: de asemenea ei solicita demiterea ministrului justiției
# Transcript: atunci nu aveam timp de vizite jucam și dormeam
# Decoded: atunci nu aveam timp de vizite jucam si dormiam
# Transcript: am avut o discuție cu el și urmează să se decidă
# Decoded: am avut o discuție cu el și urmează să se decidă
# Transcript: toți sunt jucători utili dar niciunul indispensabil
# Decoded: toți sunt jucători utili dar niciunul indispensabil
# Transcript: femei sunt
# Decoded: see you soon
# Transcript: este vorba despre bun simț și bunăvoință a declarat grigorov
# Decoded: este vorba despre bun simt și bunăvoință a declarat grigoro
# Transcript: dea puterea fi acum ești de casa noastră
# Decoded: de a puterea fi acum ieșit de casa noastră
# Transcript: noi trebuie să luptăm pentru locuri fruntașe în clasament
# Decoded: noi trebuie să luptăm pentru locuri fruntașe în clasament
# Transcript: credeți că există vreo diferență între meseriașii de acum și cei de altădată
# Decoded: credeți că există vreo diferență între meseriașii de acum și cei de altă dată
# Transcript: șoferul tirului a scăpat fără nicio leziune
# Decoded: șoferul tirului a scăpat fără nicio leziune
# Transcript: cinci din râmnicu vâlcea vor pleca vineri optsprezece septembrie la milano
# Decoded: 5 din rumnicul vulcea vor pleca vineri 18 septembrie la milano
# Transcript: credincioșii bărbații întro parte și femeile în cealaltă sau rugat în fața fațadei de vest a capitoliului
# Decoded: predincioșii bărbații întro parte și femeile în cealaltă sau rugat în fața fațadei de veste a capitoliului
# Transcript: poliția rutieră a amplasat astăzi radare pe de ne șase
# Decoded: poliția rutieră a înplasat astăzi radar pe dn6
# Transcript: băimăreanul urăște lipsa de punctualitate și fățărnicia
# Decoded: băi mărianul urăște lipsa de punctualitate și fățărnicia
# Transcript: ho ho câți poftești
# Decoded: sau cu ancăți postești
# Transcript: în foarte multe
# Decoded: în foarte multe
# Transcript: o știre din îndepărtata irlandă ar trebui și ea să ne dea serios de gândit
# Decoded: o știre din îndepărta tailandă ar trebui și ea să ne dea serios de gândit
# Transcript: tatăl ei lucra în fostul combinat siderurgic iar familia la urmat
# Decoded: tatăl ei lucra în fostul combinații de rugic iar familia la urmat
# Transcript: după o vară plină de tensiune învățământul românesc trece întro altă etapă
# Decoded: după o vară plină de tensiune neînvățământul românesc trece întro altă etapă
# Transcript: autoritățile locale așteaptă precizări de la nivel central
# Decoded: autoritățile locale așteaptă precisări de la nivel central
# Transcript: am fost luat prin surprindere de oferta stelei
# Decoded: am fost luat prin surprindere de oferta stelei
# Transcript: aceasta este o idee bună
# Decoded: aceasta este o idee bună
# Transcript: baie comună pe fiecare palier
# Decoded: baie comună pe fiecare palier
# Transcript: după primele cercetări se pare că șoferul autoturismului fiat punto a pierdut controlul volanului
# Decoded: după primele cercetări se pare că șoferul autoturismului fiat punto a pierdut controlul volanului
# Transcript: dintre aceștia paisprezece sunt de etnie rromă
# Decoded: dintre aceștia 14 sunt de etnie romă
# Transcript: nu sunt supărat pe mihai
# Decoded: nu sunt supărat pe mihai
# Transcript: rezistați să consumați numai fructe legume și miere
# Decoded: rezistați să consumați numai fructe legume și miere
# Transcript: fără jeturi de apă și spumă din abundență
# Decoded: părăgeturi de apă și spumă din abundență
# Transcript: pentru virgil melente a fost altfel
# Decoded: pentru virgil melente a fost altfel
# Transcript: pe lângă câini bătrâni avem și căței foarte drăguți și inteligenți
# Decoded: pe langa câini bătrâni avem și căței foarte drăguți și inteligenți
# Transcript: concluziile le trageți singuri
# Decoded: conclusiile le trageți singuri
# Transcript: nu mai aveau la chioșc și am fost sfătuit să vin aici
# Decoded: nu mai aveau la chiosc și am fost fătuiți să vin aici
# Transcript: replica arabilor a venit miercuri prin vocea președintelui clubului kalifah suleiman
# Decoded: replică arabilor a venit miercuri prin vocea președintelui clubului califax suleiman
# Transcript: detest foarte mult la oameni lipsa de respect și de caracter a unora
# Decoded: detest foarte mult la oameni lipsa de respect și de caractera unora
# Transcript: acum ia scris și lui gigi becali dar nu a primit răspuns
# Decoded: acum ia scris și lui gigi becali dar nu a primit răspuns
# Transcript: a fost un actor foarte talentat
# Decoded: a fost un actor foarte talentat
# Transcript: da pe lângă muzică te ocupi și de radio
# Decoded: dar pe lângă muzică te ocup și de radio
# Transcript: e un sentiment aparte când îi vezi pe toți că dansează
# Decoded: e un sentiment aparte când îi vezi pe toți că dansează
# Transcript: potrivit organizatorilor bugetul festivalului se ridică la două sute mii de euro
# Decoded: potrivit organizatorilor bugetul festivalului se ridică la 200000 de euro
# Transcript: doamne nu știu dacă ai la știință ori ba dar eu slujesc la poarta raiului de multă vreme
# Decoded: doamne nu stiu daca ai la stinta o rbat dar eu sujesc la poarta raiului de multa vreme
# Transcript: datorită acestui procedeu tradițional produsul rezultat este unul dulce și sănătos
# Decoded: datorită a acestui procedeu tradițional produsul rezultat este unul dulce și sănatos
# Transcript: ei stau foarte bine din punct de vedere fizic
# Decoded: iestau foarte bine din punct de vedere fizic
# Transcript: în cele trei zile nu se lucrează
# Decoded: în cele trei zile nu se lucrează
# Transcript: neam înțeles cu ei pentru împrumutul jucătorului pentru opt luni
# Decoded: neam înțeles cu ei pentru un prumutul jucătorului pentru 8 luni
# Transcript: în acest moment gestionarea deșeurilor se face în baza prevederilor din autorizația integrată de mediu
# Decoded: nacest moment gestionarea deșeurilor se face în baza prevederilor din autorizația integrată de mediu
# Transcript: ei ivane destul deacum țiai trăit traiul și țiai mâncat mălaiul de milostiv milostiv ești de bun la inimă bun ai fost nui vorbă
# Decoded: ei ivane destul de acum țiai trăit traiul și țiai mâncat mălaiul de milostiv milostiv ești de bun la inimă bun ai fost nui vorbă
# Transcript: panait sârbu din bucurești
# Decoded: panait sârbu din bucurești
# Transcript: ivan atunci cuprins de fiori pe loc sa dezmețit a căzut în genunchi dinaintea lui dumnezeu și a zis
# Decoded: ivan atunci cu prinzi de fiori pe loc sa dezmețit a căzut în genum dinaintea lui dumnezeu și a zis
# Transcript: învinuiții au fost luați joi și duși la audieri la bucurești
# Decoded: învinuitii au fost luați joi și duși la udier la bucurești
# Transcript: în trei ore ajung din constanța la monteoru spune un turist constănțean
# Decoded: în trei ore ajung din constanța la mânteorul spune un turist constanțian
# Transcript: primul client al polițiștilor a fost și primul sancționat
# Decoded: primul client al polițiștilor a fost și primul sanționat
# Transcript: târgul reunește importatori producători și comercianți din toată țara și cu produse de toate felurile
# Decoded: cârgul reunește importatori producători și comercianți din toată țara și cu produse de toate felurile
# Transcript: în prezent nimeni nu deține suprafețe cultivate cu viță nobilă
# Decoded: în prezent nimeni nu deține suprafetie cultivate cu viță nobilă
# Transcript: atunci sfântul petre zice cu mirare
# Decoded: atunci sfântul petre zice cu mirare
# Transcript: acolo au doi antrenori de excepție
# Decoded: acolo au doi antrenori de excepție
# Transcript: nai grijă petre zise dumnezeu
# Decoded: nai grija petre zise dumnezeu
# Transcript: arhiepiscopia este titlu onorific
# Decoded: αρχιεπίσκοπια είστε τίτλου ονορύφη
# Transcript: precizează gheorghe crivac unul dintre prorectorii universității pitești
# Decoded: precizează gheorghe crivac unul dintre prorectorii universității pitești
# Transcript: parfumul reflectă atitudinea și stilul unic al unei femei a spus cântăreața
# Decoded: arfumul reflectă atitudinea și stilul unic al unei femei a spus cântăreața
# Transcript: până în luna septembrie alte peste treizeci de autorizații au fost eliberate pentru construcțiile rezidențiale din banat
# Decoded: până un luna septembrie alte peste 30 de autorizații au fost eliberate pentru construcțiile rezidențiale din banat
# Transcript: ce alte colaborări vei avea pe viitor
# Decoded: ce alte colaborări vei avea pe viitor
# Transcript: după ce iau administrat îngrijirile de urgență medicii lau dus la reanimare unde se află sub supraveghere de specialitate
# Decoded: după ce iau administrat îngrijirile de urgență medicii lau dus la reanimare unde se află sub supraveghere de specialitate
# Transcript: potrivit directorului medical al spitalului de pediatrie galați
# Decoded: potrivit directorului medical al spitalului de pediatrie galact
# Transcript: și am spus clar că așa ceva nu pot accepta
# Decoded: și am spus clar că așa ceva nu pot accepta
# Transcript: o simțim și noi din greu
# Decoded: o simțim și noi din greu
# Transcript: toți cei care se vor implica în această campanie participă la o tombolă cu premii
# Decoded: tos cei care se vor implica în această campanie participă la o tombolă cu premii
# Transcript: noi am lipit pe uși afișe cu metodologia cazărilor ca să nu mai existe neclarități a completat iordache
# Decoded: noi am lipit pe uși afișe cu metodologia cazărilor ca să nu mai existe neclarități a completat iordache
# Transcript: guleai peste guleai ivane căci altfel înnebunești de urât zicea el
# Decoded: guleai peste guleai ivanecă ce altfel îndebunești de urât zice a el
# Transcript: compania mai are activități în domenii precum imobiliare tehnologie și energie
# Decoded: compania mai are activități în domeni precum imobiliare tehnologie și energie
# Transcript: și doi ani mai târziu când au adăugat complexului un grup sanitar
# Decoded: și doi ani mai târziu când au adăugat complexului un grup sanitar
# Transcript: chiar dacă șiau adjudecat alegerile ei au pierdut majoritatea absolută în parlament
# Decoded: chiar deacă șiau adjudecat alegerile ei au pierdut majoritatea absolută în parlament
# Transcript: detestă snobismul și lipsa bunului simț
# Decoded: detestă snobizmul și lipsa bunului simț
# Transcript: aceste insule sunt denumite teritoriile de nord de către japonia și kurile de sud de către ruși
# Decoded: aceste insule sunt denumite teritoriile de nord de către japonia și curile de sud de către ruși
# Transcript: era odată un rus pe care îl chema ivan
# Decoded: era o dată un rus pe care îl chema ivan
# Transcript: avem în medie cam treizeci de spectacole pe an
# Decoded: avem în medie cam 30 de spectacole pe an
# Transcript: apoi începe a bate în poartă
# Decoded: apoi începe a bate în poartă
# Transcript: o altă săptămână nebună a trecut peste noi
# Decoded: o altă săptămână nebună a trecut peste noi
# Transcript: prefectul loredana alexandru a fost premiată de comisia internațională pentru protecția fluviului dunărea
# Decoded: prefectul loredana alexandru a fost premiată de comisia internațională pentru protecția fluvilui dunărea
# Transcript: am adoptat un stil de viață naturist am eliminat până și carnea
# Decoded: am adoptat un stil de viață naturist am eliminat până și carnea
# Transcript: toți fotbaliștii vor să plece
# Decoded: toți fotbaliștii vor să plece
# Transcript: începe să consume droguri alcool și recurge la tentative de suicid
# Decoded: începe să consume droguri alcool și recurge la tentative de suicid
# Transcript: de asemenea la debut sa aflat și fundașul vali năstase
# Decoded: de asemenea la debut sa aflat și fundașul valii năstase
# Transcript: femei sunt
# Decoded: see you soon
# Transcript: domnul bergodi era bine venit la meci chiar dacă dumnealui nu mai face parte din staff
# Decoded: domnul bergodi era binevenit la meci chiar dacă dumnealui nu mai face parte din stat
# Transcript: așteptăm nominalizarea pesede pentru postul vacant
# Decoded: așteptăm nominalizarea pe sede pentru postul vacant
# Transcript: încaltea cea fi a fi dar degeaba nare să fie
# Decoded: încă altia ce a fi a fi dar degeaba nare să fie
# Transcript: suntem pensionari deci am dat după putere a declarat mihail ciulma din constanța
# Decoded: suntem prensionari de ce am dat după putere a declarat mihail ciulma din constanța
# Transcript: una performantă este extrem de scumpă nu ne permitem așa ceva
# Decoded: una performantă este extrem de scumpă nu ne permitem așa ceva
# Transcript: tinerii reșițeni preferă muzica de club și agitația petrecerilor house
# Decoded: tinerii reșițeni preferă muzica de club și agitația petrecerilor hause
# Transcript: căci trebuie să vă spun că boierul acela avea o pereche de case mai deo parte în care se zice că locuia necuratul
# Decoded: că își trebuie să vă spun că boierul acela avea o pereche de case mai de o parte în care se zice că locul ea necuratul
# Transcript: drumul a fost blocat mai multe ore
# Decoded: drumul a fost blocat mai multe ore
# Transcript: pericolul imens era ca întreaga economie să se prăbușească
# Decoded: pericolul imens era ca întreaga economie să se prăbușească
# Transcript: până la pauză sa întâmplat tot
# Decoded: pandii la pauză sa întâmplat tot
# Transcript: în acest caz nu se poate spune de o schimbare
# Decoded: în acest caz nu se poate spune de o schimbare
# Transcript: și atunci odată începe a bate în poartă strigând
# Decoded: și atunci odată începe a baten poartă strigând
# Transcript: aveam chiar și clase de cincizeci de elevi
# Decoded: aveam chiar și clase de cinzeci de elevi
# Transcript: ultima grevă de proporții în sănătate a fost în două mii
# Decoded: ultima grevă de proporții în sănătate a fost în 2000
# Transcript: apoi stai dar că are chira socoteală cum văd eu
# Decoded: apoi stai de arcare chiras o coteală cum văd eu
# Transcript: nu a murit dar a rămas mutilată și asta ma marcat
# Decoded: nu a murit dar a rămas mutilată și asta ma marcat
# Transcript: cultura germană postbelică pacifistă a primit o lovitură puternică
# Decoded: cultura germană pozbelică pacifistă a primit o lovitură puternică
# Transcript: ca ea mai este o singură femeie la unitatea de la bacău
# Decoded: ca ea mai este o singura femeie la unitatea de la bacau
# Transcript: suntem la a patra ediție în baia mare
# Decoded: suntem la a patra ediție în baia mare
# Transcript: nu există niciun dubiu
# Decoded: non esiste nessun dubbio
# Transcript: viitorul era promițător dar am fost demis pe nedrept
# Decoded: vitorul era promițător dar am fost demis pe nedred
# Transcript: așa începe fiecare antrenament pe care sportivii slătineni îl desfășoară zilnic pe tatamii din sala de antrenamente
# Decoded: așa începe fiecare antrenament pe care sportivii slătineni îl desfășoară zilnic pe tatamii din sala de antrenamente
# Transcript: antrenorul florin ispas a trimis în teren echipa mecea
# Decoded: andrenorul florin ispas a trimis în teren echipa mecea
# Transcript: numi place răutatea și prostia
# Decoded: numi place răutatea și prostia
# Transcript: nu pot fi vândute pentru că prețul ar fi unul foarte mare
# Decoded: nu pot fi vândute pentru că prețul ar fi unul foarte mare
# Transcript: alt domeniu ar fi turismul
# Decoded: al domenio arfiturismo
# Transcript: nu au fost probleme deosebite
# Decoded: nu au fost probleme deosebite
# Transcript: au promis că vor activa comisia constituțională în parlament
# Decoded: au promis că vor activa comisia constituțională în parlament
# Transcript: toți elevii de la lombardo radice vorbesc fluent limba italiană
# Decoded: toți eleivi de la lombarcu de radice vorbesc fluent limba italiană
# Transcript: am împărtășit din informațiile primite în cadrul proiectului
# Decoded: am împărtășit din informațiile primite în cadrul proiectului
# Transcript: rețeta e similară numai că în aluat a pus și iaurt și lea dat altă formă
# Decoded: rețeta e similară numai că în aluat a pus și iaurt și lea dat altă formă
# Transcript: vom discuta în consiliul de administrație pentru a vedea cum putem să o ajutăm a declarat ieri anghel petrescu
# Decoded: vom discuta în consiliul de administrație pentru a vedea cum putem să o ajutăm a declaratieri anghel petrescu
# Transcript: învinuiții au fost luați joi și duși la audieri la bucurești
# Decoded: învinuiții au fost luați joi și duși la udieri la bucurești
# Transcript: trebuie să practicăm un joc foarte bun și să fim concentrați
# Decoded: trebuie să practicăm un joc foarte bun și să fim concentrați
# Transcript: în urma impactului pasagera din dreapta bmwului a fost cea mai grav rănită
# Decoded: în urma impactului pasagerea din dreapta bmwului a fost cea mai grav rănită
# Transcript: și ducânduse el scoate moartea de la închisoare șii zice
# Decoded: și ducânduse el scoate moartea de la închisoare și zice
# Transcript: ofițerii din cadrul ijepefe
# Decoded: ofițerii din cadrul igpf
# Transcript: ecuadorul și columbia vor avea primul contact diplomatic
# Decoded: ecuadorul și columbia vor avea primul contact diplomatic
# Transcript: am primit bani pentru a ne achita datoriile la zi
# Decoded: am primit bani pentru a neachita datorile la zi
# Transcript: depinde de client
# Decoded: depinde de cliente
# Transcript: nu există nici un dubiu
# Decoded: nu există niciun dubiu
# Transcript: anul acesta niciun părinte nu a fost decăzut
# Decoded: anul acesta niciun părinte nu a fost decăzut
# Transcript: echipa de elevi a concurat în trei probe
# Decoded: echipa de elevii a concurat în trei probe
# Transcript: ia am căptușit niște iepuroi și am de gând săi jumulesc
# Decoded: am câptușit niște iepurei și am de gând săi jumulesc
# Transcript: apă otrăvită după cum veți vedea în cele ce urmează
# Decoded: apoi o trăvită după cum veți vedea în cele ce urmează
# Transcript: la acest spectacol sunt valabile și abonamentele de premieră
# Decoded: la acest spectacol sunt valabile și abonamentele de premieră
# Transcript: în bucurești era chiar mai rău doisprezece avorturi la o naștere
# Decoded: în bucurești era chiar mai rău 12 avorturi la unaștere
# Transcript: nu era obligatoriu să facă asta
# Decoded: nu era obligatoriu să facă asta
# Transcript: oficialii cefere iași susțin că nu au fost victime
# Decoded: oficiali ceferiași susțin că nu au fost victime
# Transcript: nu toți însă se pot ridica la un anumit nivel
# Decoded: nu toți însă se pot ridica la un anumit nivel
# Transcript: azi dau doar un examen de maturitate
# Decoded: azi dau doar un examen de maturitate
# Transcript: apoi dumnezeu pornește cu sfântul petre și cât ici cât cole ajung pe ivan careo ducea tot întrun cântec de parcă era toată lumea a lui
# Decoded: apoi dumnezeu pornește cu sfântul petre și câtici cât cole ajung pe ivan care o ducea tot întrun cântec de parcă era toată lumea lui
# Transcript: dar de unde știi așa de bine că mă cheamă ivan
# Decoded: dar de unde știi așa de bine că mă cheamă ivan
# Transcript: concluziile le trageți singuri
# Decoded: concluziile le trageți singuri
# Transcript: dar se vede că pân acum lea fost și lor veleatul
# Decoded: dar se vede că până acum lea fost și lor veleaturi
# Transcript: numi place când văd necredința în dumnezeu
# Decoded: numi place când văd necredința în dumnezeu
# Transcript: dracul de la poartă gândind că e vreun mușteriu vechi deal lor deschide și atunci numai iaca ce se trezesc pe neașteptate cu ivan turbinca
# Decoded: dracul de la poartă gândind că e vreu mușteriu vechi de al lor deschide și atunci nu mai ia ca ce se trezesc pe neașteptate cu ivan turbincă
# ...
# Transcript: dintr o dată mingea a căzut în curtea unui localnic
# Decoded: dintro dată minge a căzut în curtea unui localnic
# Transcript: pe scena casei de cultură a sindicatelor din pitești
# Decoded: pe scena casei de cultura sindicatelor din pitești
# Transcript: cele de acum sunt lucruri făcute să se strice a mai spus acesta
# Decoded: cele de acum sunt lucruri făcute să se strici ea mai spus acesta
# Transcript: tabacioc este
# Decoded: que está bajo quiebre
# Transcript: palestinienii cer un îngheț complet al construcțiilor amintește agerpres
# Decoded: palestinienii cer un îngheț complet al construcțiilor amintește agerpres
# Transcript: la fiecare zgomot tresăream de câte ori auzeam sirene mă ascundeam
# Decoded: la fire care îți gomotresăream de câte ore auzeam sirene mă ascundeam
# Transcript: zilnic traficul rutier de pe cele mai mari străzi ale orașului este îngreunat de căruțași
# Decoded: zilnic traficul utier de pe cele mai mari străzi ale orașului este îngreunat de căruțași
# Transcript: nu poate spune însă că și le mai dorește ca înainte
# Decoded: nu poate spune însă că și le mai dorește ca înainte
# Transcript: a venit acasă anul trecut în august
# Decoded: a venit acasă anul trecut în august
# Transcript: sfântul petre atunci deschide și când colo se trezește cu ivan
# Decoded: sfântul petre atunci deschide și când colo se trezește cu ivan
# Transcript: vom face tot posibilul să existe mai multă înțelegere cooperare și încredere reciprocă a adăugat el
# Decoded: vom face tot posibilul să existe mai multă înțelegere cooperare și încredere reciprocă a adăugat el
# Transcript: noi nu avem posibilitatea de ai controla așa cum neam dori
# Decoded: noi nu avem posibilitatea de icon întro lașa cum neam dorit
# Transcript: în această perioadă au început însă să crească solicitările
# Decoded: în această perioadă au început însă să crească solicitarile
# Transcript: dumitru petrescu zona cam
# Decoded: dumitru petresku u zona k
# Transcript: stilul baroc este evidențiat de elementele structurale
# Decoded: stilul baroc este evidenția de elementele structurale
# Transcript: mă descurc nam probleme spune valentin ușor îmbujorat
# Decoded: mă descurc nam probleme spune valentin ușor îmbujurat
# Transcript: în schimb firmele lui penescu primeau doar contravenții
# Decoded: în schimb firmele lui penescu primiau doar contraventii
# Transcript: problema cu sergiu toader este una personală
# Decoded: problema cu sergiul toader este una personală
# Transcript: sunt în asistențe și pe lângă mașini de foarte mult timp
# Decoded: sunt în asistențe și pe lângă mașini de foarte mult timp
# Transcript: și cum ajunge la poarta raiului din afară se și pune acolo de strajă și stă neadormit zi și noapte tot întruna fără să se clintească din loc
# Decoded: și cum ajunge la poarta raiului din afară se și pune acolo de strajă și stă neadormit zi și nuaptă tot întruna fără să se clintească din lou
# Transcript: dacă vecinii nu reclamă noi nu putem depista spargerile de pereți ilegale din apartamente
# Decoded: dacă vecinii nu reclamă noi nu putem depista spargerile de pereți legale din apartamente
# Transcript: sătenii spun că așa incendiu nu au mai văzut până acum
# Decoded: să te ni spun că așa incendiu nu au mai văzut până acum
# Transcript: primarii spun că nu mai au bani de salarii
# Decoded: primarei spun că nu mai au bani de salarii
# Transcript: navă dumnezeu mia dat eu dau și dumnezeu iar mia da că are de unde
# Decoded: na văd dumnezeu mia dat eu dau și dumnezeu iar mia dat care de unde
# Transcript: artiștii armâni îmbrăcați în costume populare tradiționale au susținut și un spectacol cu melodii tradiționale populare din zona moscopole
# Decoded: artiștii armâni îmbrăcați în costume populare tradiționali au susținut și un spectacol cu melodii tradiționale populare din zona moscopole
# Transcript: asta dacă vor să se simtă bine
# Decoded: asta dacă vor să se simtă bine
# Transcript: în an de criză solistul de la simplu a dat lovitura
# Decoded: în an de criză solistul de la simplu a dat lovitura
# Transcript: ianis hai să nu ne grăbim
# Decoded: ianis hai să nu ne grăbim
# Transcript: până în luna septembrie alte peste treizeci de autorizații au fost eliberate pentru construcțiile rezidențiale din banat
# Decoded: până în luna septembrie alte peste 30 de autorizații au fost eliberate pentru construcțiile rezidențiale din banat
# Transcript: trăim întro sărăcie intelectuală în favoarea goanei materialiste
# Decoded: trăim întro sărăcie intelectuală în favoarea goanei materialiste
# Transcript: vânzarea cailor lipițani a scăzut considerabil anul acesta
# Decoded: vânzarea caiilor lipițani a scăzut considerabil anul acesta
# Transcript: nus ivane ce mă tot chihăiești de cap
# Decoded: nus ivane ce mă tot ihăiești de ca
# Transcript: copilul a fost transportat la spitalul județean brașov pentru îngrijiri de specialitate
# Decoded: opilul a fost transportat la spitalul județean brașov pentru un grijir de specialitate
# Transcript: sindicaliștii au anunțat aseară că vor bloca activitatea de la nouă octombrie
# Decoded: sindicaliștii au anunțat aseară că vor bloca activitatea de la 9 octombrie
# Transcript: talk showul sa transformat dintro dezbatere în spectacol
# Decoded: tauk showul sa transformat din trot de zbatere în spectacol
# Transcript: trebuie să încercăm mereu să ne redescoperim să luptăm
# Decoded: trebuie să încercăm mereu să ne redescoperim să luptăm
# Transcript: eu nu mai înțeleg pentru ce dau acei bani
# Decoded: eu nu mai înțeleg pentru ce dau acei bani
# Transcript: această procedură se alătură politeții manifestate de taximetriști în ultima perioadă
# Decoded: această procedură se alătură politiei manifestate de taximetriști în ultima perioadă
# Transcript: nu avem decât varianta victoriei
# Decoded: nu avem decât varianta victoriei
# Transcript: ultima grevă de proporții în sănătate a fost în două mii
# Decoded: ultima grevă de proporții în sănătate a fost în 2000
# Transcript: mihail stănculescu a apelat și el la acest sistem
# Decoded: mihail stănculescu a apelați și el la acest sistem
# Transcript: mai ales soderling care a adus trei puncte
# Decoded: mai ales soderling care a adus 3 puncte
# Transcript: acesta va mai reprezenta uue în deplasările în străinătate
# Decoded: acesta va mai reprezenta oei în deplasările în străinătate
# Transcript: este vorba de un sistem de climatizare arhitectură electronică și suspensii inovatoare
# Decoded: este vorba de un sistem de climatizare arhitectură electronică și suspensii inovatoare
# Transcript: baie comună pe fiecare palier
# Decoded: vai com uma perfecaria palier
# Transcript: nu pot fi vândute pentru că prețul ar fi unul foarte mare
# Decoded: nu pot fi vândute pentru că prețul ar fi unul foarte mare
# Transcript: două sute cincizeci și trei din codul penal și pentru săvârșirea infracțiunii de neglijență în serviciu
# Decoded: 253 din codul penal și pentru săvârșirea infracțiunii de negligență în serviciu
# Transcript: ei ivane ce mai direguiești moartea na mai venit peaici
# Decoded: ei ivane ce mai direguiei moartea na mai venit pe aici
# Transcript: dacă îți place poți să îți formezi și îndemânarea
# Decoded: dacă îți place pot săți formez și îndemânarea
# Transcript: statul nu trebuie să mai fie o povară pentru cetățeni
# Decoded: statul nu trebuie să mai fie o povară pentru cetățeni
# Transcript: am peste patruzeci de meciuri în cupele europene
# Decoded: am peste 40 de meciuri în cupele europene
# Transcript: și atunci principalii pierzători sunt cei foarte buni
# Decoded: și atunci principalii pierzători sunt cei foarte buni
# Transcript: este o operație riscantă dar ne rugăm să scape
# Decoded: este o operație riscantă dar ne rugăm să scape
# Transcript: departajarea se face pe probe de cincizeci de metri care trebuiesc parcurse în zece secunde
# Decoded: departajarea se face pe probe de 50 de metri care trebuiesc parcurse în 10 secundă
# Transcript: pe el nul răpunea până pe la șapte mai spune ema
# Decoded: pe el nu răpunea până pe la șapte mai spune emma
# Transcript: între timp a fost solicitată urmărirea pensionarului prin sistemul automat
# Decoded: între timp a fost solicitată urmărirea pensionarului prin sistemul automat
# Transcript: deocamdată din constatările pe care leam făcut
# Decoded: deocamdată din constatările pe care leam făcut
# Transcript: federer nu sa regăsit a dus dorul unui prim serviciu solid și astfel argentinianul a făcut cinci la doi
# Decoded: federer nu sa regăsit adus dorul unui prim serviciu solid și astfel argentinianul a făcut 5 la 2
# Transcript: cristi tănase va juca maximum o repriză cu feceme bacău
# Decoded: tristită nase va jucă maximum o repriză cu feceme bacău
# Transcript: am văzut că îi place să cânte și să danseze
# Decoded: am văzut că îi place să cânte și să danseze
# Transcript: în ce privește reabilitarea monumentului există două teorii
# Decoded: în ce privește rehabilitarea monumentului există două teori
# Transcript: nu au fost probleme deosebite
# Decoded: nu au fost probleme deosebite
# Transcript: la spital au venit cu sufletul la gură și câteva mămici
# Decoded: la spital au venit cu sufletul la gură și câteva mămici
# Transcript: partida se joacă pe stadionul emil alexandrescu din iași
# Decoded: partida se joacă pe stadionul emil alexandrescu din iasi
# Transcript: am întâlnit o echipă bună care ar putea face pasul spre prima ligă
# Decoded: am întâlnit o echipă bună care ar putea face pasul spre prima ligă
# Transcript: tergiversarea rezolvării lucrurilor ar putea duce la o situație grea și nu vor mai fi bani pentru salarii
# Decoded: tergiversarea rezolvării lucrurilor ar putea duce la o situație grea și nu vor mai fi bani pentru salarii
# Transcript: dacă este util pentru țară sunt dispus să lucrez în orice post
# Decoded: dacă este util pentru țară sunt dispus să lucrez în orice post
# Transcript: lumea internetului a adus și o nouă forță estetică
# Decoded: lumea internetului a adus și o nouă forță estetică
# Transcript: în două mii patru am pierdut alegerile
# Decoded: în 2004 am pierdut alegerile
# Transcript: acesta este evident visul unei nopți de vară care va rămâne un vis
# Decoded: acesta este evident visul unei nobzi de vară care va rămâne un vis
# Transcript: am avut o discuție cu el și urmează să se decidă
# Decoded: am avut o discuție cu el și urmează să se decidă
# Transcript: deocamdată lista este deschisă spune magda georgescu purtător de cuvânt al ajofm maramureș
# Decoded: deocamdată lista este deschisă spune magda gheorghezcu purtător de cuvânt al ajof maramurești
# Transcript: autoturismul a fost proiectat în celălalt picior al podului
# Decoded: autoturismul a fost proiectat în celălalt picior al podului
# Transcript: tricolorii vor întâlni sâmbătă reprezentativa ungariei
# Decoded: tricolorii vor întâlni sămbătă reprezentativă a ungariei
# Transcript: tot aici ești ivane tot
# Decoded: tot aici ești ivane tot
# Transcript: bărbatul este cercetat penal de polițiștii din ardud pentru lovire și alte violențe
# Decoded: bărbatul este cer cetat penal de polițiștii din ardut pentru lovire și alte violențe
# Transcript: explicația cu necorelarea vitezelor este una simplistă
# Decoded: explicatia cum e corelarea vitezelor este una simplista
# Transcript: citește despre revolta organizațiilor catolice din spania pe adevărul
# Decoded: citește despre revoltă a organizațiilor catolice din spania pe adevărul
# Transcript: și am spus clar că așa ceva nu pot accepta
# Decoded: și am spus clar că așa ceva nu pot accepta
# Transcript: cei aniversați primesc cadouri din partea primăriei municipiului alba iulia
# Decoded: cei aniversați primesc cadour din partea primăriei municiului alba iulia
# Transcript: dar bine ivane iar ai de gând să mă chinuiești cu turbinca ceea a ta
# Decoded: dar bine ivane iar ai de gând să mă chinuiești cu turbinca cea ta
# Transcript: astfel ar apărea competiții între școli și între profesori
# Decoded: astea lear apărea competiții între școli și între profesorii
# Transcript: fără jeturi de apă și spumă din abundență
# Decoded: părăjeturi de apă și spumă din abundență
# Transcript: aici a avut loc disputa caiaciștilor pe râurile drau și isel
# Decoded: aici a avut loc disputa caiacistilor pe răurile drau și isel
# Transcript: una performantă este extrem de scumpă nu ne permitem așa ceva
# Decoded: una performantă este extrem de scumpă nu ne permitem așa ceva
# Transcript: mă simt mai puternic am mai multă energie
# Decoded: mă simt mai puternic am mai multă energie
# Transcript: filat promite reglementarea limbii române
# Decoded: filat promete reglementare a limbii romane
# Transcript: votchi este
# Decoded: вот киесто
# Transcript: lea crescut tatăl invalid de război și mătușa paraschiva
# Decoded: lea crescut tatăl invalid de război și mătușa paraschiva
# Transcript: aceștia își vor pierde locul de muncă
# Decoded: acestia își vor pierde locul de muncă
# Transcript: datoria noastră este să aducem pavajul la același nivel
# Decoded: datoria noastră este să aducem pavajul la același nivel
# Transcript: acest lucru nu sa mai întâmplat niciodată
# Decoded: acest lucru nu sa mai întâmplat niciodată
# Transcript: deacum rămâi la mine ivane și pentru că miai curățit casa de draci am să te țin ca pe palmă
# Decoded: de acum rămâi la mine ivane și pentru că miai curățit casa de dragi am să te țin ca pe palnă
# Transcript: ei las cornoraților de miți mai pica vrodată în mână turbinca are să vă știe de știre
# Decoded: ei las cornuraților de mit mai picavro dat în mână turbin ca are să vă știe deștire
# Transcript: de demult erai tu mătrășit din lumea asta și ajuns de batjocura dracilor dacă nuți intra dumnezeu în voie mai mult decât însuși fiului său
# Decoded: de demult erai tu mătrășit din lumea asta și ajuns de baciocura dracilor dacă nuți intra dumnezeu în voie mai mult decât în suș fiului său
# Transcript: și tocmai acolo porunci să culce și pe ivan
# Decoded: și tocmai acolo porunci să culce și pe ivan
# Transcript: îmi place mâncarea bună mai ales laptele brânza și dulciurile
# Decoded: îmi place mâncarea bună mai ales laptele brânza și dulciurile
# Transcript: debitorii cer măsuri de protecție față de abuzuri ale băncilor
# Decoded: debitorii cer măsuri de protecție față de abuzuri ale băncilor
# Transcript: în acest caz lipsa fondurilor face ca istoria să rămână
# Decoded: în acest caz lipsa fondurilor face ca istoria să rămână
# Transcript: întrun cuvânt rusia dintotdeauna
# Decoded: întrun cuvânt rusia din totdeauna
# Transcript: oamenii se simțeau legați de acel loc
# Decoded: oamenii se simțeau legați de acelor
# Transcript: toți jucătorii de la echipă lucrează la finalizare
# Decoded: toți jucătorii de la echipă lucrează la finalizare
# Transcript: acum nu iam mai luat pentru că adăpostul era plin cu câini
# Decoded: acum nu iam mai luat pentru ca adapostul era plin cu caini
# Transcript: avea piciorușul rupt își aduce aminte tânăra
# Decoded: avea piciorușul rupt își aduce aminte tânăra
# Transcript: la rândul lor edilii sau scuzat că nu sunt bani
# Decoded: la rândul lor edili sau scuzat că nu sunt bani
# Transcript: am avut probleme foarte mari
# Decoded: am avut probleme foarte mari
# Transcript: specialiștii din domeniu le vor oferi și stafuri pentru alegerea corectă
# Decoded: specialiștii din domeniul le vor oferi și stafuri pentru alegerea corectă
# Transcript: asociația nu avea statut legal atunci când am devenit eu președinte
# Decoded: asociația nu avea statut legal atunci când am devenit eu președintă
# Transcript: dar cel mai experimentat din acest punct de vedere este maftei
# Decoded: dar cel mai experimentat din acest punct de vedere este maftei
# Transcript: dacă nu sa intervenit la timp normal că acum sunt grămezi uriașe
# Decoded: dacă nu sa intervenit la timp normal că acum sunt grămezi uriașă
# Transcript: în acest an doi șiau pierdut serviciul din acest motiv
# Decoded: în acest an doi șiau pierdut serviciul din acest motiv
# Transcript: procurorii îi bănuiesc însă și de alte douăzeci de spargeri
# Decoded: procurorii îi bănuiesc însă și de alte 20 de spargeri
# Transcript: citiți întreg articolul cum leii falși sau înmulțit în criză
# Decoded: citiți întreg articolul cum lei falși sau umulțit în criză
# Transcript: nu trebuie un alt program economic al guvernului
# Decoded: nu trebuie un alt program economic al guvernului

# %%
# 500 iterations + sv56
print(f"WER: {wer_all.mean() * 100:.2f}[%]")
print(f"CER: {cer_all.mean() * 100:.2f}[%]")
# Out:
# WER: 15.51[%]
# CER: 5.41[%]

# %%
# 50 iterations + sv56
print(f"WER: {wer_all.mean() * 100:.2f}[%]")
print(f"CER: {cer_all.mean() * 100:.2f}[%]")
# Out:
# WER: 15.18[%]
# CER: 5.39[%]

# %%
# 50 iterations
print(f"WER: {wer_all.mean() * 100:.2f}[%]")
print(f"CER: {cer_all.mean() * 100:.2f}[%]")
# Out:
# WER: 15.24[%]
# CER: 5.46[%]

# %%
# print(f"WER: {wer_all.mean() * 100:.2f}[%]")
# print(f"CER: {cer_all.mean() * 100:.2f}[%]")
# Out:
# WER: 15.18[%]
# CER: 5.39[%]

# %% [markdown]
# - 50 iterations
#     - WER: 15.24[%]
#     - CER: 5.46[%]
#
# - 50 iterations + sv56
#     - WER: 15.18[%]
#     - CER: 5.39[%]
#
# - 500 iterations + sv56
